# %% [markdown]
# ```json
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# 🏥 HyperKvasir Exploratory Data Analysis (EDA) Master Notebook\n",
#     "> **Dự án:** GIEndoDL - Phân loại tổn thương nội soi tiêu hóa bằng Deep Learning\n",
#     "> **Dữ liệu:** Master Metadata (`data/processed/hyperkvasir_master_metadata.csv` - 10,662 ảnh, 23 lớp)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import pandas as pd\n",
#     "import matplotlib.pyplot as plt\n",
#     "import seaborn as sns\n",
#     "import json\n",
#     "from pathlib import Path\n",
#     "\n",
#     "metadata_path = Path('../data/processed/hyperkvasir_master_metadata.csv')\n",
#     "df = pd.read_csv(metadata_path)\n",
#     "print(f'✅ Tải thành công Master Metadata: {len(df):,} ảnh x {len(df.columns)} thuộc tính!')\n",
#     "df.head(3)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 1. Thống kê Phân tầng 23 Lớp & Imbalance Ratio"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "class_counts = df['class_name'].value_counts()\n",
#     "ir = class_counts.max() / class_counts.min()\n",
#     "print(f'🔥 Imbalance Ratio: {ir:.2f} : 1 (Max: {class_counts.max()} vs Min: {class_counts.min()})')\n",
#     "print(f'📊 Phân bố theo 4 nhóm lớn:')\n",
#     "print(df['super_category'].value_counts())"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 2. Hiển thị Dashboard Đánh giá Toàn diện Dữ liệu"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "from IPython.display import Image, display\n",
#     "display(Image(filename='../docs/figures/08_hyperkvasir_23_classes_grid.png'))\n",
#     "display(Image(filename='../docs/figures/03_hyperkvasir_pareto_imbalance.png'))\n",
#     "display(Image(filename='../docs/figures/09_class_morphological_similarity_heatmap.png'))"
#    ]
#   }
#  ],
#  "metadata": {
#   "language_info": {
#    "name": "python"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 2
# }
